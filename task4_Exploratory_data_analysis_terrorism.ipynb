# %% [markdown]
# ### GRIP - The Sparks Foundation

# %% [markdown]
# ### Data Science and Business Analytics

# %% [markdown]
# Author : Manasa R

# %% [markdown]
# IDE : Jupyter Notebook

# %% [markdown]
# Data :https://bit.ly/2TK5Xn5

# %% [markdown]
# ### TASK 4: EXPLORATORY DATA ANALYSIS - TERRORISM

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Dataset

# %%
data=pd.read_csv(r'D:\globalterrorismdb_0718dist.csv',encoding='latin1')

# %% [markdown]
# ### Describing Dataset

# %%
data.head() #printing top 5 rows
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.tail() #printing last 5 rows
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
data.shape #printing number of rows and columns
# Out:
# (181691, 135)

# %%
data.dtypes #printing data types of values
# Out:
# eventid       float64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG         int64
# INT_IDEO        int64
# INT_MISC        int64
# INT_ANY         int64
# related        object
# Length: 135, dtype: object

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
data.isnull().sum() #checking for null values
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# ### Extracting required columns

# %%
data=data[['iyear','imonth','iday','country_txt','provstate','region_txt','city','latitude','longitude','attacktype1_txt',
           'nkillu','nwound','targtype1_txt','summary','gname','weaptype1_txt','motive',]]

# %%
data
# Out:
#         iyear  imonth  iday         country_txt        provstate  \
# 0        1970       7     2  Dominican Republic              NaN
# 1        1970       0     0              Mexico          Federal
# 2        1970       1     0         Philippines           Tarlac
# 3        1970       1     0              Greece           Attica
# 4        1970       1     0               Japan          Fukouka
# ...       ...     ...   ...                 ...              ...
# 181686   2017      12    31             Somalia  Middle Shebelle
# 181687   2017      12    31               Syria         Lattakia
# 181688   2017      12    31         Philippines      Maguindanao
# 181689   2017      12    31               India          Manipur
# 181690   2017      12    31         Philippines      Maguindanao
#
#                          region_txt           city   latitude   longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
data.isnull().sum()
# Out:
# iyear                   0
# imonth                  0
# iday                    0
# country_txt             0
# provstate             421
# region_txt              0
# city                  434
# latitude             4556
# longitude            4557
# attacktype1_txt         0
# nkillu              10313
# nwound              16311
# targtype1_txt           0
# summary             66129
# gname                   0
# weaptype1_txt           0
# motive             131130
# dtype: int64

# %% [markdown]
# As seen, provstate,city,latitude,longitude,summary,motive ,nkillu and nwound have null values. Hence we assign 0 to the null rows and group nkillu and nwound under casualities

# %%
data['nkillu']=data['nkillu'].fillna(0)
data['nwound']=data['nwound'].fillna(0)
data['Casualities']=data['nkillu']+data['nwound']

# %%
data.head()
# Out:
#    iyear  imonth  iday         country_txt provstate  \
# 0   1970       7     2  Dominican Republic       NaN
# 1   1970       0     0              Mexico   Federal
# 2   1970       1     0         Philippines    Tarlac
# 3   1970       1     0              Greece    Attica
# 4   1970       1     0               Japan   Fukouka
#
#                     region_txt           city   latitude   longitude  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# 4                    East Asia        Fukouka  33.580412  130.396361
#
#                   attacktype1_txt  nkillu  nwound  \
# 0                   Assassination     1.0     0.0
# 1     Hostage Taking (Kidnapping)     0.0     0.0
# 2                   Assassination     1.0     0.0
# ...

# %%
data['Casualities'].count()
# Out:
# 181691

# %%
data.corr()
# Out:
#                 iyear    imonth      iday  latitude  longitude    nkillu  \
# iyear        1.000000  0.000139  0.018254  0.166933   0.003917  0.021252
# imonth       0.000139  1.000000  0.005497 -0.015978  -0.003880  0.004031
# iday         0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003225
# latitude     0.166933 -0.015978  0.003423  1.000000   0.001463 -0.013170
# longitude    0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000587
# nkillu       0.021252  0.004031 -0.003225 -0.013170  -0.000587  1.000000
# nwound       0.017484  0.003178 -0.001082  0.015920   0.000205  0.443326
# Casualities  0.020675  0.003805 -0.001808  0.009899   0.000013  0.651885
#
#                nwound  Casualities
# iyear        0.017484     0.020675
# imonth       0.003178     0.003805
# iday        -0.001082    -0.001808
# latitude     0.015920     0.009899
# longitude    0.000205     0.000013
# nkillu       0.443326     0.651885
# nwound       1.000000     0.968724
# ...

# %%
sb.heatmap(
    data.corr(),
    xticklabels=data.corr().columns,
    yticklabels=data.corr().columns,
    annot=True,
    linewidth=1.0,
    cmap='icefire'
)

# %% [markdown]
# ### Visual Representation

# %%
year=data['iyear'].unique()
year_c=data['iyear'].value_counts(dropna=False).sort_index()
plt.figure(figsize=(20,10))
sb.barplot(x=year,y=year_c,palette='Dark2_r')
plt.xticks(rotation=50)
plt.xlabel('YEAR',fontsize=15)
plt.ylabel('NUMBER OF ATTACKS',fontsize=15)
plt.title('YEAR vs NUMBER OF ATTACKS IN EACH YEAR',fontsize=15)
plt.show()

# %%
data['iyear'].value_counts()
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: iyear, dtype: int64

# %%
plt.rcParams["figure.figsize"] = 20,10
sb.barplot(x = data["country_txt"].value_counts()[:20].index, y=data["country_txt"].value_counts()[:20].values,palette='Greens_r')
plt.xticks(rotation=50)
plt.xlabel("Country", size=15)
plt.ylabel("Number", size=15)
plt.title("COUNTRY WISE ATTACKS", size=15)
# Out:
# Text(0.5, 1.0, 'COUNTRY WISE ATTACKS')

# %%
df=data['country_txt'].value_counts()
print('Top 5:')
print(df.head(5))
print('\nLast 5:')
print(df.tail(5))
# Out:
# Top 5:
# Iraq           24636
# Pakistan       14368
# Afghanistan    12731
# India          11960
# Colombia        8306
# Name: country_txt, dtype: int64
#
# Last 5:
# Andorra                1
# Wallis and Futuna      1
# Antigua and Barbuda    1
# Falkland Islands       1
# Vatican City           1
# Name: country_txt, dtype: int64

# %%
plt.rcParams["figure.figsize"] = 20,10
sb.barplot(x = data["city"].value_counts()[:20].index, y=data["city"].value_counts()[:20].values,palette='GnBu_r')
plt.xticks(rotation=50)
plt.xlabel("City", size=15)
plt.ylabel("Number", size=15)
plt.title("CITY WISE ATTACKS", size=15)
# Out:
# Text(0.5, 1.0, 'CITY WISE ATTACKS')

# %%
df = data[['iyear','nkillu']].groupby(['iyear']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
df.plot(kind='bar',alpha=0.7,ax=ax4)
plt.xticks(rotation = 50)
plt.title("NUMBER OF DEATHS",fontsize=15)
plt.ylabel("NUMBER OF PEOPLE KILLED",fontsize=15)
plt.xlabel('YEAR',fontsize=15)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %%
c=['darkblue','blue','skyblue','lightblue','pink','violet','magenta','purple','darkviolet']
data['attacktype1_txt'].value_counts().plot(kind='bar',figsize=(20,10),color=c)
plt.xticks(rotation = 70)
plt.xlabel("TYPE OF ATTACKS",fontsize=15)
plt.ylabel("NUMBER OF ATTACKS",fontsize=15)
plt.title("NUMBER OF ATTACKS BASED ON TYPE OF ATTACKS",fontsize=15)
plt.show()

# %%
data['attacktype1_txt'].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
data[['attacktype1_txt','nkillu']].groupby(data['attacktype1_txt'],axis=0).sum().plot(kind='bar',figsize=(20,10),color='olive')
plt.xticks(rotation = 70)
plt.xlabel("TYPE OF ATTACKS",fontsize=15)
plt.ylabel("NUMBER OF KILLS",fontsize=15)
plt.title("NUMBER OF KILLS BASED ON TYPE OF ATTACKS",fontsize=15)
plt.show()

# %%
data[['attacktype1_txt','nwound']].groupby(data['attacktype1_txt'],axis=0).sum().plot(kind='bar',figsize=(20,10),color='firebrick')
plt.xticks(rotation = 70)
plt.xlabel("TYPE OF ATTACKS",fontsize=15)
plt.ylabel("NUMBER OF WOUNDED",fontsize=15)
plt.title("NUMBER OF WOUNDED BASED ON TYPE OF ATTACKS",fontsize=15)
plt.show()

# %%
plt.rcParams["figure.figsize"] = 20,10
sb.barplot(x = data["targtype1_txt"].value_counts()[:20].index, y=data["targtype1_txt"].value_counts()[:20].values,palette='PRGn_r')
plt.xticks(rotation=80)
plt.xlabel("TARGET TYPE", size=15)
plt.ylabel("NUMBER OF ATTACKS", size=15)
plt.title("ATTACKS BASED ON TARGETS", size=15)
# Out:
# Text(0.5, 1.0, 'ATTACKS BASED ON TARGETS')

# %%
data['gname'].value_counts()[:10]  #top 10 terrorist groups
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: gname, dtype: int64

# %%
kills=data.pivot_table(columns='country_txt',values='nkillu',aggfunc='sum')
kills
# Out:
# country_txt  Afghanistan  Albania  Algeria  Andorra  Angola  \
# nkillu           39384.0     42.0  11066.0      0.0  3043.0
#
# country_txt  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  ...  \
# nkillu                       0.0      490.0     37.0       23.0     30.0  ...
#
# country_txt  Vietnam  Wallis and Futuna  West Bank and Gaza Strip  \
# nkillu           1.0                0.0                    1500.0
#
# country_txt  West Germany (FRG)  Western Sahara   Yemen  Yugoslavia  Zaire  \
# nkillu                     97.0             1.0  8776.0       119.0  324.0
#
# country_txt  Zambia  Zimbabwe
# nkillu         70.0     154.0
#
# [1 rows x 205 columns]

# %%
df=data[['attacktype1_txt','nkillu']].groupby('attacktype1_txt',axis=0).sum()
df
# Out:
#                                        nkillu
# attacktype1_txt
# Armed Assault                        160297.0
# Assassination                         24920.0
# Bombing/Explosion                    157321.0
# Facility/Infrastructure Attack         3642.0
# Hijacking                              3718.0
# Hostage Taking (Barricade Incident)    4478.0
# Hostage Taking (Kidnapping)           24231.0
# Unarmed Assault                         880.0
# Unknown                               32381.0

# %%
df=data[['attacktype1_txt','nwound']].groupby('attacktype1_txt',axis=0).sum()
df
# Out:
#                                        nwound
# attacktype1_txt
# Armed Assault                         77366.0
# Assassination                         13887.0
# Bombing/Explosion                    372686.0
# Facility/Infrastructure Attack         3765.0
# Hijacking                             17001.0
# Hostage Taking (Barricade Incident)    3966.0
# Hostage Taking (Kidnapping)            6446.0
# Unarmed Assault                       14027.0
# Unknown                               14725.0

# %%
df=data[['gname','nkillu']].groupby('gname',axis=0).sum()
print('First 10 rows')
print(df.head(10))
print('Last 10 rows')
print(df.tail(10))
# Out:
# First 10 rows
#                                                     nkillu
# gname
# 01-May                                                 2.0
# 09-Feb                                                11.0
# 14 K Triad                                             0.0
# 14 March Coalition                                     5.0
# 14th of December Command                               0.0
# 15th of September Liberation Legion                    0.0
# 16 January Organization for the Liberation of T...     1.0
# 1920 Revolution Brigades                              15.0
# 19th of July Christian Resistance Brigade              1.0
# 1st of May Group                                       0.0
# Last 10 rows
#                                        nkillu
# gname
# Zimbabwe People's Army (ZIPA)             0.0
# Zintani Militia                           0.0
# Zionist Resistance Fighters               1.0
# Zomi Revolutionary Army (ZRA)             0.0
# ...

# %% [markdown]
# ### Conclusions

# %% [markdown]
# Maximum number of attacks took place in the year 2014 (16903 attacks)

# %% [markdown]
# Least number of attacks took place in the years 1971 and 1973 (471 and 473 attacks respectively)

# %% [markdown]
# The country with highest number of attacks is Iraq (24636 attacks)

# %% [markdown]
# One of the highest affected city is Bhagdad

# %% [markdown]
# Highest number of people killed was in the year 2014

# %% [markdown]
# Highest number of attacks were through bombing/explosion (88255 attacks)

# %% [markdown]
# Highest number of kills were due to armed assaults type of attack (160297.0 kills)

# %% [markdown]
# Highest number of wounded were due to bombing/explosion type of attack (372686.0 wounded)

# %% [markdown]
# Target group of maximum attacks was private citizens and property

# %% [markdown]
# Highest number of attacks was by group named by taliban
